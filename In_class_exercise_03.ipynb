# %% [markdown]
# <a href="https://colab.research.google.com/github/PinnaSaiVarun/saivarun_INFO5731_-Fall2021/blob/main/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/29/2021, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

The basic purpose of sentiment analysis from twitter data is to assess whether the tweets users send on twitter have positive or negative feelings.
In this work, both text classifications and text mining will be employed, with text mining bringing in data from Twitter and text classification classifying data into smaller sections such as sentences, words, characters, punctuation, and so on.

Features:
The features that might be useful are given below:
1. Finding the character length for each sentiment.
2. Word count.
3. Average chacter length per word.
4. Special characters count.
5. Number Counts.
6. Stop Words.

'''
# Out:
# '\nPlease write you answer here:\n\nThe basic purpose of sentiment analysis from twitter data is to assess whether the tweets users send on twitter have positive or negative feelings.\nIn this work, both text classifications and text mining will be employed, with text mining bringing in data from Twitter and text classification classifying data into smaller sections such as sentences, words, characters, punctuation, and so on.\n\nFeatures:\nThe features that might be useful are given below:\n1. Finding the character length for each sentiment.\n2. Word count.\n3. Average chacter length per word.\n4. Special characters count.\n5. Number Counts.\n6. Stop Words.\n\n'

# %% [markdown]
# Question 2 (20 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
# You code here (Please add comments in the code):

sentence = ['The basic purpose of sentiment analysis from twitter data is to assess whether the tweets users send on twitter have positive or negative feelings' , 'In this work, both text classifications and text mining will be employed, with text mining bringing in data from Twitter and text classification classifying data into smaller sections such as sentences, words, characters, punctuation, and so on' , 'Features The features that might be useful are given below:' , '1. Finding the character length for each sentiment.', '2. Word count.' , '3. Average chacter length per word.' , '4. Special characters count.' , '5. Number Counts.' , '6. Stop Words.']

# %%
# Importing dataframe
import pandas as pd
dataframe = pd.DataFrame(sentence, columns = ['sentence'])
dataframe
# Out:
#                                             sentence
# 0  The basic purpose of sentiment analysis from t...
# 1  In this work, both text classifications and te...
# 2  Features The features that might be useful are...
# 3  1. Finding the character length for each senti...
# 4                                     2. Word count.
# 5                3. Average chacter length per word.
# 6                       4. Special characters count.
# 7                                  5. Number Counts.
# 8                                     6. Stop Words.

# %%
# Remove punctuation from the input
dataframe['sentence'] = dataframe['sentence'].str.replace('[^\w\s]','')
dataframe
# Out:
#                                             sentence
# 0  The basic purpose of sentiment analysis from t...
# 1  In this work both text classifications and tex...
# 2  Features The features that might be useful are...
# 3  1 Finding the character length for each sentiment
# 4                                       2 Word count
# 5                  3 Average chacter length per word
# 6                         4 Special characters count
# 7                                    5 Number Counts
# 8                                       6 Stop Words

# %%
# Printing number of repeated words frequency
rw = (dataframe['sentence'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
rw.columns = ['words','term freq']
rw
# Out:
#               words  term freq
# 0              text          4
# 1               and          3
# 2            mining          2
# 3              data          2
# 4          employed          1
# 5              will          1
# 6                In          1
# 7                in          1
# 8        characters          1
# 9             words          1
# 10   classification          1
# 11      classifying          1
# 12             with          1
# 13         sections          1
# 14             from          1
# 15        sentences          1
# 16             work          1
# 17      punctuation          1
# 18         bringing          1
# 19             such          1
# 20             both          1
# 21               as          1
# 22               so          1
# 23          smaller          1
# 24          Twitter          1
# 25               on          1
# 26             this          1
# 27  classifications          1
# 28             into          1
# ...

# %%
import tweepy
import pandas as pd

consumer_key = "Sl9QlYe2uIYFB4c56ht3suQpx"
consumer_secret = "itmSoGGJBHAjnhcy0jZOyBHEEB9oYztj5mLBAa7yJm4tRAb2ai"
access_token = "1438705493510344707-C3jtWFSrEjfyj0dtBY09lXUVsDL0oi"
access_token_secret = "XEnNE1Mn6WupA0XnSV8aVNYXrV1k9no4iq6BMDZEOAV5d"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)


text_query = 'TwitterBestFandom'
max_tweets = 250

# Print the top tweets
Twitter = tweepy.Cursor(api.search,q=text_query,lang='en', location = 'Korea', since = '2021-03-16').items(max_tweets)
 
# Code for creating the nested tweets
twitter_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count, tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
 
# Creating the dataframe
dataframe = pd.DataFrame(tweets_list)
dataframe


Twitter = pd.DataFrame()
Twitter['Tweets'] = dataframe[0]
Twitter
# Out:
#                                                Tweets
# 0   RT @woohyoons: 180911 - WOOHYUN's first win 🏆\...
# 1   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 2   RT @gaemer_elf: Throwback to when Heechul wrot...
# 3   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 4   RT @fancamjoon: 160725 Dope - Ulsan Summer Fes...
# 5   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 6   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 7   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 8   RT @fanatic_got7_: Thread: GOT7 members' most ...
# 9   RT @fanatic_got7_: Thread: GOT7 members' most ...
# 10  RT @kookbeingextra: jungkook's face when they ...
# 11  #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 12  RT @CoolPlanetstore: Bathroom Kitchen Sink Dra...
# 13  #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...
# 14  Check it out tomorrow\nhttps://t.co/p5iC57Wzh0...
# 15  RT @fanatic_got7_: Thread: GOT7 members' most ...
# ...

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import *
from nltk.corpus import stopwords

new = pd.DataFrame()
new['Tweets'] = dataframe[0]
Twitter = Tweets

# Count the number of sentence
new['Tweets'] = new['Tweets'].apply(sent_tokenize)
Twitter['Sentence_Count'] = new['Tweets'].apply(len)

# Count the number of words in a sentence
Twitter['Word_Count'] = Twitter['Tweets'].apply(lambda x: len(str(x).split(" ")))

# Count number of characters in a sentence
Twitter['Char_Count'] = Twitter['Tweets'].str.len()

# Removes the stopwords
stop = stopwords.words('english')
Twitter['Stopwords'] = Twitter['Tweets'].apply(lambda x: len([x for x in x.split() if x in stop]))

# Count the special characters
Special_Characters = '[@_!#$%^&*()<>?/\|}{~:]'
SC_Tuple = tuple(Special_Characters)
Twitter['Special_Characters_Count'] = Twitter['Tweets'].apply(lambda x: len([x for x in x.split() if x.startswith(SC_Tuple)]))

Twitter['Numerics_Count'] = Twitter['Tweets'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))

Twitter['Upper_Count'] = Twitter['Tweets'].apply(lambda x: len([x for x in x.split() if x.isupper()]))

Twitter
# Out:
#                                                Tweets  ...  Upper_Count
# 0   RT @woohyoons: 180911 - WOOHYUN's first win 🏆\...  ...            2
# 1   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# 2   RT @gaemer_elf: Throwback to when Heechul wrot...  ...            1
# 3   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# 4   RT @fancamjoon: 160725 Dope - Ulsan Summer Fes...  ...            2
# 5   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# 6   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# 7   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# 8   RT @fanatic_got7_: Thread: GOT7 members' most ...  ...            3
# 9   RT @fanatic_got7_: Thread: GOT7 members' most ...  ...            3
# 10  RT @kookbeingextra: jungkook's face when they ...  ...            1
# 11  #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...            1
# ...

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
'''
The Chi-square test is used to select features. We want to pick features that are heavily dependent on the reaction when we're selecting features. Because the observed count is close to the expected count when two features are independent, the Chi-Square value is less. The fact that the Chi-Square score is so high implies that the independence hypothesis is false.

After the collection of cleaned words, these can be compared to the data dictionary and sentiments numeric can be assigned and total sentiment can be obtained.
Hence tweets sentiments as positive or negative will be shown.
'''
# Out:
# "\nThe Chi-square test is used to select features. We want to pick features that are heavily dependent on the reaction when we're selecting features. Because the observed count is close to the expected count when two features are independent, the Chi-Square value is less. The fact that the Chi-Square score is so high implies that the independence hypothesis is false.\n\nAfter the collection of cleaned words, these can be compared to the data dictionary and sentiments numeric can be assigned and total sentiment can be obtained.\nHence tweets sentiments as positive or negative will be shown.\n"

# %%
# Code for polarity and subjectivity 
def sentiment(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None

# Add the results to the dataframe
Twitter['Polarity_Sentiment'] = Twitter['Tweets'].apply(sentiment)
Twitter['Polarity'] = Twitter['Polarity_Sentiment'].apply(lambda x: x[0])

# If the polarity is positive then sentiment is printed as positive else printed as negative

def sentiment(Polarity):
  if Polarity>0:
    return 'Positive'
  else:
    return 'Negative'

# Prints the final outputs
Twitter['Sentiment'] = Twitter['Polarity'].apply(sentiment)
Twitter
# Out:
#                                                Tweets  ...                           Polarity_Sentiment
# 0   RT @woohyoons: 180911 - WOOHYUN's first win 🏆\...  ...                  (0.525, 0.3666666666666667)
# 1   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...                                   (0.0, 0.0)
# 2   RT @gaemer_elf: Throwback to when Heechul wrot...  ...                                   (0.6, 1.0)
# 3   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...                                   (0.0, 0.0)
# 4   RT @fancamjoon: 160725 Dope - Ulsan Summer Fes...  ...                                   (0.0, 0.0)
# 5   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...                                   (0.0, 0.0)
# 6   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...                                   (0.0, 0.0)
# 7   #TeamGOT7 #SoompiAwards #TwitterBestFandom #GO...  ...                                   (0.0, 0.0)
# ...
